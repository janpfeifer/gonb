// %%
%%
fmt.Println("Hello World")
// Out:
// Hello World

// %%
%%
fmt.Println("Hello World"
// Out:
// <style>
// .gonb-err-location {
// 	background: var(--jp-err-color2);
// 	border-radius: 3px;
// 	border-style: dotted;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// }
// .gonb-err-hover-area {
// 	cursor: pointer;
// }
// .gonb-err-hover-area:hover .gonb-err-location {
// 	border-width: 2px;
// 	border-style: solid;
// 	border-color: var(--jp-border-color2);
// }
// .gonb-err-hover-area:hover .gonb-cell-line-info {
// 	border-color: var(--jp-border-color2);
// }
// .gonb-err-context {
// 	display: none;
// }
// .gonb-err-hover-area:hover + .gonb-err-context {
// 	background: var(--jp-dialog-background);
// 	border-radius: 3px;
// 	border-style: solid;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// 	display: block;
// 	white-space: pre-wrap;
// 	word-break: break-word;
// 	font-family: monospace;
// }
// .gonb-err-line {
// 	border-radius: 3px;
// 	border-style: dotted;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// 	background-color: var(--jp-rendermime-err-background);
// 	font-weight: bold;
// }
// .gonb-cell-line-info {
// 	background: var(--jp-layout-color2);
// 	color: #999;
// 	margin: 0.1em;
// 	border: 1px solid var(--jp-border-color1);
// 	padding-left: 0.2em;
// 	padding-right: 0.2em;
// }
// </style>
// <div class="lm-Widget p-Widget lm-Panel p-Panel jp-OutputArea-child">
// <div class="lm-Widget p-Widget jp-RenderedText jp-mod-trusted jp-OutputArea-output" data-mime-type="application/vnd.jupyter.stderr" style="font-family: monospace; white-space: pre-wrap;">
//
// <span class="gonb-err-hover-area"><span class="gonb-cell-line-info">Cell[2]: Line 2</span> <span class="gonb-err-location">/tmp/gonb_0435bcdd/main.go:5:26: </span></span>missing ',' before newline in argument list (and 1 more errors)
// <div class="gonb-err-context">
//
// func main() {
// 	flag.Parse()
// <div class="gonb-err-line">fmt.Println(&#34;Hello World&#34;
// </div>
// }
//
// </div>
//
// <br/>
//
// </div>
// parsing go files in TempDir "/tmp/gonb_0435bcdd": /tmp/gonb_0435bcdd/main.go:5:26: missing ',' before newline in argument list (and 1 more errors)

// %%
import "github.com/pkg/errors"

func StartBistromaticDrive() error {
	return errors.New("FATAL EXCEPTION: Bistromathic Drive stuck in Neutral. A Swiss waiter provided a mathematically flawless, itemized receipt, destroying the Recipriversexcluson field. Propulsion offline until someone argues over the fondue.")
}

%%
err := StartBistromaticDrive()
log.Fatalf("Stuck in Switzerland: %+v", err)
// Out:
// 2026/06/07 13:06:20 Stuck in Switzerland: FATAL EXCEPTION: Bistromathic Drive stuck in Neutral. A Swiss waiter provided a mathematically flawless, itemized receipt, destroying the Recipriversexcluson field. Propulsion offline until someone argues over the fondue.
// main.StartBistromaticDrive
// 	 [[ Cell [3] Line 4 ]] /tmp/gonb_0435bcdd/main.go:10
// main.main
// 	 [[ Cell [3] Line 8 ]] /tmp/gonb_0435bcdd/main.go:16
// runtime.main
// 	/home/janpf/sdk/go1.26.3/src/runtime/proc.go:290
// runtime.goexit
// 	/home/janpf/sdk/go1.26.3/src/runtime/asm_amd64.s:1771
// exit status 1
// <style>
// .gonb-err-location {
// 	background: var(--jp-err-color2);
// 	border-radius: 3px;
// 	border-style: dotted;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// }
// .gonb-err-hover-area {
// 	cursor: pointer;
// }
// .gonb-err-hover-area:hover .gonb-err-location {
// 	border-width: 2px;
// 	border-style: solid;
// 	border-color: var(--jp-border-color2);
// }
// .gonb-err-hover-area:hover .gonb-cell-line-info {
// 	border-color: var(--jp-border-color2);
// }
// .gonb-err-context {
// 	display: none;
// }
// .gonb-err-hover-area:hover + .gonb-err-context {
// 	background: var(--jp-dialog-background);
// 	border-radius: 3px;
// 	border-style: solid;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// 	display: block;
// 	white-space: pre-wrap;
// 	word-break: break-word;
// 	font-family: monospace;
// }
// .gonb-err-line {
// 	border-radius: 3px;
// 	border-style: dotted;
// 	border-width: 1px;
// 	border-color: var(--jp-border-color2);
// 	background-color: var(--jp-rendermime-err-background);
// 	font-weight: bold;
// }
// .gonb-cell-line-info {
// 	background: var(--jp-layout-color2);
// 	color: #999;
// 	margin: 0.1em;
// 	border: 1px solid var(--jp-border-color1);
// 	padding-left: 0.2em;
// 	padding-right: 0.2em;
// }
// </style>
// <div class="lm-Widget p-Widget lm-Panel p-Panel jp-OutputArea-child">
// <div class="lm-Widget p-Widget jp-RenderedText jp-mod-trusted jp-OutputArea-output" data-mime-type="application/vnd.jupyter.stderr" style="font-family: monospace; white-space: pre-wrap;">
//
// 	<span class="gonb-err-hover-area"><span class="gonb-cell-line-info">Cell[3]: Line 4</span> <span class="gonb-err-location">/tmp/gonb_0435bcdd/main.go:10</span></span>
// <div class="gonb-err-context">
// )
//
// func StartBistromaticDrive() error {
// <div class="gonb-err-line">	return errors.New(&#34;FATAL EXCEPTION: Bistromathic Drive stuck in Neutral. A Swiss waiter provided a mathematically flawless, itemized receipt, destroying the Recipriversexcluson field. Propulsion offline until someone argues over the fondue.&#34;)
// </div>}
//
//
// </div>
//
// <br/>
//
// 	<span class="gonb-err-hover-area"><span class="gonb-cell-line-info">Cell[3]: Line 8</span> <span class="gonb-err-location">/tmp/gonb_0435bcdd/main.go:16</span></span>
// <div class="gonb-err-context">
//
// func main() {
// 	flag.Parse()
// <div class="gonb-err-line">err := StartBistromaticDrive()
// </div>log.Fatalf(&#34;Stuck in Switzerland: %+v&#34;, err)
//
//
// </div>
//
// <br/>
//
// </div>
// exit status 1
